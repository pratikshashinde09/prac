# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv("HousingData.csv")

# %%
df.columns
# Out:
# Index(['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX',
#        'PTRATIO', 'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
df.sample(5)
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 378  23.64820   0.0  18.10   0.0  0.671  6.380  96.2  1.3861   24  666
# 67    0.05789  12.5   6.07   0.0  0.409  5.878  21.4  6.4980    4  345
# 289   0.04297  52.5   5.32   0.0  0.405  6.565  22.9  7.3172    6  293
# 177   0.05425   0.0    NaN   0.0  0.510  6.315  73.4  3.3175    5  296
# 252   0.08221  22.0   5.86   0.0  0.431  6.957   6.8  8.9067    7  330
#
#      PTRATIO       B  LSTAT  MEDV
# 378     20.2  396.90  23.69  13.1
# 67      18.9  396.21   8.10  22.0
# 289     16.6  371.72   9.51  24.8
# 177     16.6  395.60   6.29  24.6
# 252     19.1  386.09   3.53  29.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 14 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   CRIM     486 non-null    float64
#  1   ZN       486 non-null    float64
#  2   INDUS    486 non-null    float64
#  3   CHAS     486 non-null    float64
#  4   NOX      506 non-null    float64
#  5   RM       506 non-null    float64
#  6   AGE      486 non-null    float64
#  7   DIS      506 non-null    float64
#  8   RAD      506 non-null    int64
#  9   TAX      506 non-null    int64
#  10  PTRATIO  506 non-null    float64
#  11  B        506 non-null    float64
#  12  LSTAT    486 non-null    float64
#  13  MEDV     506 non-null    float64
# dtypes: float64(12), int64(2)
# memory usage: 55.5 KB

# %%
df.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.shape
# Out:
# (506, 14)

# %%
df.fillna(df.mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
df.shape
# Out:
# (506, 14)

# %%
sns.heatmap(df.corr(),annot=True,square=True)
# Out:
# <Axes: >

# %%
X = df.drop(['MEDV'], axis = 1)
y = df['MEDV']

# %%
x_train,x_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=10)

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

# %%
x_train.shape, x_test.shape
# Out:
# ((379, 13), (127, 13))

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
    Dense(128, activation='relu', input_shape=(13,)),
    Dense(64, activation='relu'),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'), 
    Dense(1)  
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# C:\Users\Ashvini Mahajan\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 128)                 │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 64)                  │           8,256 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 12,673 (49.50 KB)
#  Trainable params: 12,673 (49.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=50,batch_size=32,validation_split=0.05)
# Out:
# Epoch 1/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - loss: 548.0323 - mae: 21.6981 - val_loss: 688.8215 - val_mae: 23.5710
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 489.2297 - mae: 20.1589 - val_loss: 570.0818 - val_mae: 21.0580
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 384.9449 - mae: 17.5531 - val_loss: 323.3824 - val_mae: 14.6828
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 138.7828 - mae: 9.4653 - val_loss: 129.7518 - val_mae: 7.1218
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 83.0863 - mae: 6.8674 - val_loss: 126.6440 - val_mae: 6.5728
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 36.5661 - mae: 4.5531 - val_loss: 127.2173 - val_mae: 6.7246
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 31.0101 - mae: 4.0333 - val_loss: 109.7819 - val_mae: 6.1485
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 23.8402 - mae: 3.6496 - val_loss: 104.2545 - val_mae: 6.0520
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 20.3528 - mae: 3.1946 - val_loss: 102.0882 - val_mae: 5.9939
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 14.8617 - mae: 2.9604 - val_loss: 99.6876 - val_mae: 5.8712
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 15.4317 - mae: 2.8937 - val_loss: 96.7365 - val_mae: 5.7609
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 13.1519 - mae: 2.6808 - val_loss: 93.3267 - val_mae: 5.6200
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 14.4121 - mae: 2.8492 - val_loss: 94.2373 - val_mae: 5.6442
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 14.1450 - mae: 2.6877 - val_loss: 89.2952 - val_mae: 5.4191
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 13.9801 - mae: 2.6882 - val_loss: 89.2800 - val_mae: 5.4127
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 12.2392 - mae: 2.5501 - val_loss: 86.9315 - val_mae: 5.2340
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 10.6804 - mae: 2.4353 - val_loss: 83.9249 - val_mae: 5.0780
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.0035 - mae: 2.3816 - val_loss: 81.6092 - val_mae: 4.9963
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.7157 - mae: 2.2998 - val_loss: 82.9366 - val_mae: 4.9788
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.7937 - mae: 2.3435 - val_loss: 79.5590 - val_mae: 4.8325
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.1510 - mae: 2.2411 - val_loss: 82.1574 - val_mae: 4.8981
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 10.6983 - mae: 2.3475 - val_loss: 84.0368 - val_mae: 4.8843
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 9.2450 - mae: 2.3208 - val_loss: 80.4623 - val_mae: 4.8345
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.1264 - mae: 2.3000 - val_loss: 78.8949 - val_mae: 4.8357
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 12.2721 - mae: 2.4240 - val_loss: 80.6064 - val_mae: 4.9172
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 9.3803 - mae: 2.2143 - val_loss: 80.3165 - val_mae: 4.8496
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.1455 - mae: 2.1138 - val_loss: 76.2190 - val_mae: 4.6680
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 9.7155 - mae: 2.2474 - val_loss: 80.0066 - val_mae: 4.8037
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 10.8388 - mae: 2.3840 - val_loss: 75.5810 - val_mae: 4.6258
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.8119 - mae: 2.0566 - val_loss: 79.0246 - val_mae: 4.7433
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 8.4098 - mae: 2.0725 - val_loss: 80.1280 - val_mae: 4.9046
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.5117 - mae: 2.1682 - val_loss: 79.8917 - val_mae: 4.8552
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.4768 - mae: 2.0950 - val_loss: 80.4031 - val_mae: 4.7698
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 7.4709 - mae: 2.0235 - val_loss: 75.1241 - val_mae: 4.6309
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 8.6117 - mae: 2.1684 - val_loss: 78.0359 - val_mae: 4.7736
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 8.1961 - mae: 2.0588 - val_loss: 75.6791 - val_mae: 4.6290
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 7.2432 - mae: 2.0079 - val_loss: 74.5297 - val_mae: 4.6123
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.7973 - mae: 2.0634 - val_loss: 78.5606 - val_mae: 4.7646
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.1885 - mae: 1.9541 - val_loss: 76.1922 - val_mae: 4.7209
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.8848 - mae: 1.9880 - val_loss: 76.9196 - val_mae: 4.7032
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.5915 - mae: 1.9356 - val_loss: 73.1597 - val_mae: 4.6158
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.5301 - mae: 2.0189 - val_loss: 77.0962 - val_mae: 4.7072
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 8.5271 - mae: 2.0419 - val_loss: 73.0252 - val_mae: 4.6732
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 7.2262 - mae: 1.9621 - val_loss: 76.1467 - val_mae: 4.6785
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 6.9117 - mae: 1.9629 - val_loss: 74.9710 - val_mae: 4.6582
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 7.3907 - mae: 2.0028 - val_loss: 73.5811 - val_mae: 4.7081
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 8.0007 - mae: 1.9784 - val_loss: 77.9999 - val_mae: 4.7891
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 7.4470 - mae: 1.9252 - val_loss: 73.3808 - val_mae: 4.6203
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.4005 - mae: 2.0042 - val_loss: 77.5140 - val_mae: 4.7935
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 7.5066 - mae: 1.9221 - val_loss: 73.2074 - val_mae: 4.7120

# %%
loss,mae=model.evaluate(x_test,y_test,verbose=0)
print(f"Mean Squared Error",loss)
print(f"Mean Absolute Error", mae)
# Out:
# Mean Squared Error 20.353717803955078
# Mean Absolute Error 2.8059725761413574

# %%
predictions = model.predict(x_test)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step

# %%
# Compute RMSE
import numpy as np
rmse = np.sqrt(mean_squared_error(y_test, predictions))
print(f"RMSE: ",rmse)
# Compute R² Score
r2 = r2_score(y_test, predictions)
print(f"R2 Score : ",r2)
# Out:
# RMSE:  4.511509367637255
# R2 Score :  0.7958253374132671

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, predictions,alpha=0.5, edgecolors='k')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color="red", linestyle="dashed")  
plt.xlabel("True Prices")
plt.ylabel("Predicted Prices")
plt.title("True Prices vs Predicted Prices")
plt.show()

# %%
# Predictions 

predicted_value = model.predict(x_test[0].reshape(1, -1))
print(f"Prediction for X_test[{0}]: {predicted_value[0]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# Prediction for X_test[0]: [26.708954]
